# %% [markdown]
# # AILAB + LeNER-BR
# This jupyter notebook is being develop to integrate the leNER-BR model described in this [article](https://cic.unb.br/~teodecampos/LeNER-Br/luz_etal_propor2018.pdf) with the AILAB text classification pipeline.

# %%
from ailab_ner.lenerbr.ner_model import NERModel
from ailab_ner.lenerbr.config import Config
from ailab_ner.preprocessing import generate_freq_dist_plot, generate_wordcloud
import pandas as pd
from nltk import word_tokenize
from nltk import data
from nltk.tokenize.punkt import PunktSentenceTokenizer
import sys

# %% [markdown]
# ### Constants

# %%
RELATIVE_PATH_TO_FOLDER = "./assets/datasets/"
DATA_FILENAME = "judicial_data"

# %% [markdown]
# ## Loading raw data

# %%
excel_filename = RELATIVE_PATH_TO_FOLDER + DATA_FILENAME + ".csv"
df_raw_data = pd.read_csv(excel_filename)

print(df_raw_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 661 entries, 0 to 660
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    661 non-null    int64
#  1   id_documento  661 non-null    int64
#  2   area1         661 non-null    object
#  3   tema1         661 non-null    object
#  4   subtema1      661 non-null    object
#  5   area2         140 non-null    object
#  6   tema2         140 non-null    object
#  7   subtema2      140 non-null    object
#  8   area3         36 non-null     object
#  9   tema3         36 non-null     object
#  10  subtema3      36 non-null     object
#  11  area4         16 non-null     object
#  12  tema4         16 non-null     object
#  13  subtema4      16 non-null     object
#  14  area5         4 non-null      object
#  15  tema5         4 non-null      object
#  16  subtema5      4 non-null      object
#  17  area6         1 non-null      object
#  18  tema6         1 non-null      object
#  19  subtema6      1 non-null      object
#  20  area7         1 non-null      object
#  21  tema7         1 non-null      object
#  22  subtema7      1 non-null      object
#  23  body          661 non-null    object
# dtypes: int64(2), object(22)
# memory usage: 124.1+ KB
# None

# %% [markdown]
# ### Treating data

# %%
df_data = pd.DataFrame(data=df_raw_data['body'])
print(df_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 661 entries, 0 to 660
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   body    661 non-null    object
# dtypes: object(1)
# memory usage: 5.3+ KB
# None

# %% [markdown]
# ### Sampling data

# %%
df_sample = df_data.sample(n=10)
print(df_sample.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 80 to 399
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   body    10 non-null     object
# dtypes: object(1)
# memory usage: 160.0+ bytes
# None

# %% [markdown]
# ### Data Visualization

# %%
print(df_sample.info())
print("Comprimento médio:", df_sample['body'].str.len().mean())
print("Desvio padrão dos comprimentos das peças:", df_sample['body'].str.len().std())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 80 to 399
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   body    10 non-null     object
# dtypes: object(1)
# memory usage: 160.0+ bytes
# None
# Comprimento médio: 130101.5
# Desvio padrão dos comprimentos das peças: 136650.4691192094

# %% [markdown]
# ## leNER-BR model

# %%
# create instance of config
config = Config()

# build model
if not model:
    model = NERModel(config)
    model.build()
    model.restore_session(config.dir_model)

tokenizer = PunktSentenceTokenizer()

# %% [markdown]
# ### Listing entities types and preparing variables

# %%
TIPOS_ENTIDADES = ['PESSOA', 'TEMPO', 'LOCAL', 'ORGANIZACAO', 'JURISPRUDENCIA', 'LEGISLACAO']
entities_docs_per_sentence_per_type = dict()
person_docs, jurisprudence_docs, time_docs = [], [], []
legislation_docs, organizations_docs, localizations_docs = [], [], []
count_entidades = dict()

for tipo in TIPOS_ENTIDADES:
    count_entidades[tipo] = 0

docs = df_sample['body'].values
tokenizer.train(docs)
print()

# %% [markdown]
# ### Splicing documents sentences and tokenizing words

# %%
# %%time
docs_tokenized = []
for doc in docs:
    entitities_in_doc = dict()
    doc_sentences = tokenizer.tokenize(doc)
    tokenized_sentences = []
    for sentence in doc_sentences:
        words = word_tokenize(sentence, language='portuguese')
        tokenized_sentences.append(words)
    docs_tokenized.append(tokenized_sentences)

print("Sentenças dividas em tokens")
print(docs_tokenized[0])
# Out:
# Sentenças dividas em tokens
# [['UNICO', 'DOC', ';', "'PRM-JFA-MG", '_61~L/J', ',', 'QJ,3', 'ENV', 'jPRM-JFA-MG', '.J', '!', '1', '!', 'LQ.', ',', 'j', '_r2', '&', 'J3', 'MINISTÉRIO', 'PÚBLICO', "'", 'FEDERAL', '.PROCURADORIA', 'DA', 'REPÚBLICA', 'NO', 'MUNICÍPIO', 'DE', 'JUIZ', 'DE', 'FORA', '-', 'MINAS', 'GERAIS', 'Oficio', 'i50iL', '/2013-', 'MPF/PRM/JF/GAB/OFM', 'Juiz', 'de', 'Fora', ',', '03', 'de', 'outubro', 'de', '2013.', 'l1ustIÍssimo', 'Senhor', 'TRIBUNAL', 'DE', 'CONTAS', 'DA', 'LJI\\IIAO', '~', 'SECRETARIA', 'DE', 'CONTROLE', 'EXTERI', "'", 'W.MG', '!'], ['RUA', 'üAMP', ',', 'NA', "'/ERDE", ',', '~~3', "'", 'I', 'José', 'Reinaldo', 'da', 'Motta', 'SALGADO', 'FILHO', '-', 'CEP', ':', '30550-340', 'PROTOCOLO', 'Secretário', 'de', 'Controle', 'Externo', 'de', 'Minas', 'Gerais', '1', "'", 'I', 'OUT', '.'], ['2013', 'Tribunal', 'de', 'Contas', 'da', 'União', 'em', 'Minas', 'Gerais', 'BELO', 'HORIZONTE', '.'], ['MG', 'Rua', 'Campina', 'Verde', ',', '593', '-', 'Salgado', 'Filho', 'HORÁRIO', 'H', "Hi'ln", 'CEP', '30.550-340', 'Belo', 'Horizonte', '-', 'MG', 'Assunto', ':', 'Apresenta', 'representação', 'l1ustIÍssimo', 'Senhor', ',', 'Com', 'os', 'meus', 'cumprimentos', ',', 'visando', 'instruir', 'a', 'Notícia', 'de', 'Fato', '1.22.001.000236/2013-46', ',', 'encaminho', 'a', 'Vossa', 'Senhoria', 'cópia', 'de', 'documentação', 'extraída', 'de', 'seus', 'autos', ',', 'servindo', 'este', 'oficio', 'de', 'REPRESENTAÇÃO', 'para', 'a', 'instauração', ',', 'por', 'este', 'TribunaL', 'do', 'devído', 'procedimento', 'para', 'apuração', 'de', 'responsabilidades', '.'], ['Atenciosamente', ',', 'Procurador', 'Regional', 'da', 'República', 'LVC', 'Rua', 'Santo', 'Antônio', '.'], ['990/1501', '-', 'Centro', '-', '.Juiz', 'de', 'For8', '-', 'M', '(', ';', '-', 'CEP', '36.016.210', 'Telefones', ':', '(', '32', ')', '4009.1250', '-', 'Fax', ':', '(', '32', ')', '4009-1280', 'Para', 'verificar', 'as', 'assinaturas', ',', 'acesse', 'www.tcu.gov.br/autenticidade', ',', 'informando', 'o', 'código', '50664025', '.'], ['!', '.'], ['\\', '_', 'MlNIsTÉRIO', 'PúBLICO', 'FEDERAL', '.'], ['PROCURADORIA', '.'], [',', 'DA', 'REPúBLICA', 'NO', 'MUNICÍPIO', 'DE', 'JUIZ', 'DE', 'FORA', '.'], ['Rua', 'Santo', 'Antônio', ',', '990', '-', 'centro', '-', 'CEP', ':', '36016-210', '-Juiz', 'de', 'ForalMG', '.'], ['Ao', 'Exmo', 'Sr', '.'], ['Or', '.'], ['Carlos', 'Bruno', 'Ferreira', 'da', 'Silva', 'Doc', 'fi', "''", 'PRM-JFA-MG-00005042/20', '13', 'Senhor', 'Procurador', ',', '-', 'Envio', 'a', '-V.', 'Ex', "'", 'o', 'presente', 'documento', 'para', 'verificação', 'da', 'possibilidade', 'de', 'autuação', 'de', '.Peça', 'Informativa', '.'], ['Outrossim', ',', 'informo', 'que', 'foi', 'realizada', 'pesquisa', 'no', "sistema'APTUS", 'com', 'os', 'seguintes', 'termos', ':', '-RODRIGO', 'DANI', '?', 'LI', 'SOUZA', ',', 'NOS9CôM10', ',', '0145.1', '1.001101-5', ',', 'JORNADA', '.'], ['Tendo', 'sido', 'localizado', 'os', 'seguintes', 'procedimentos', ':', '1.22.001.000370/2011-82', ',', '1.22.001.000107/2013-', '58', 'e', '1.22.001.00011512013-02', '.'], ['-', 'Juiz', 'de', 'Fora', ',', '19', 'de', 'agos', 'de', '2013', '.'], ['-liNfA', 'MA', '(', 'A', '.'], ['POS', 'T', 'êc', '.'], ['À', 'Ma', 'SU', 'I', "'", 'DESPACHO', '(', ')', 'Arquive-se', 'na', 'PRMlJF', ',', 'mediante', 'registro', 'no', 'sistema', 'próprio', ',', 'comunii', ':', ':ando-se', 'ao', 'representante', 'que', 'os', 'fatos', 'narrados', 'não', 'configuram', 'lesão', 'aos', 'interesses', 'cuja', 'defesa', 'incUll1l', ':', '!', '.eao', 'Ministério', 'Público', 'promover', ',', 'com', 'a', 'advertência', 'dé', 'que', 'desta', 'decisão', 'cabe', 'recurso', 'administrativo', 'á', 'ser', 'interposto', 'nestâ', '.'], ['Unidade', ',', 'no', 'prazo', 'de', '10', '(', 'dez', ')', 'dias', '.'], ['.'], ['(', ')', 'Arquive-se', 'na', 'PRMlJF', ',', 'mediante', 'registro', 'no', 'sistema', 'próprio', ',', 'comul\\icando-se', 'ao', 'representante', 'que', 'a', 'narrativa', 'dos', 'fatos', 'nãõ', "'", 'contém', 'elementos', 'mínimos', 'capazes ...
# CPU times: user 12.2 s, sys: 55 ms, total: 12.3 s
# Wall time: 12.3 s

# %% [markdown]
# ### Using model to identify entities

# %%
# %%time
docs_labels = []
for doc in docs_tokenized:
    entitities_in_doc = dict()
    label_doc = []
    for token_sentence in doc:
        preds = model.predict(token_sentence)
        label_doc.append(preds)
        for i, word in enumerate(token_sentence):
            ''' Removendo sufixo de tipo de entidades'''
            if preds[i][0:2] in ['B-', 'I-', 'E-', 'S-']:
                preds[i] = preds[i][2:]
            if preds[i] != 'O':
                ent_type = preds[i]
                count_entidades[ent_type] += 1
                if ent_type not in entitities_in_doc.keys():
                    entitities_in_doc[ent_type] = [word]
                else:
                    entitities_in_doc[ent_type].append(word)
        
    ''' Separando cada bolsa de palavras por tipo de entididade '''
    if 'PESSOA' in entitities_in_doc.keys():
        person_docs.append(" ".join(entitities_in_doc['PESSOA']))
    else:
        person_docs.append(" ")

    if 'JURISPRUDENCIA'  in entitities_in_doc.keys():
        jurisprudence_docs.append(" ".join(entitities_in_doc['JURISPRUDENCIA']))
    else:
        jurisprudence_docs.append(" ")

    if 'TEMPO' in entitities_in_doc.keys():
        time_docs.append(" ".join(entitities_in_doc['TEMPO']))
    else:
        time_docs.append(" ")

    if 'LEGISLACAO'  in entitities_in_doc.keys():
        legislation_docs.append(" ".join(entitities_in_doc['LEGISLACAO']))
    else:
        legislation_docs.append(" ")

    if 'ORGANIZACAO'  in entitities_in_doc.keys():
        organizations_docs.append(" ".join(entitities_in_doc['ORGANIZACAO']))
    else:
        organizations_docs.append(" ")

    if 'LOCAL'  in entitities_in_doc.keys():
        localizations_docs.append(" ".join(entitities_in_doc['LOCAL']))
    else:
        localizations_docs.append(" ")

    docs_labels.append(label_doc)
print("Identificação de entidades")
# Out:
# Identificação de entidades
# CPU times: user 9min 39s, sys: 23.6 s, total: 10min 3s
# Wall time: 4min 53s

# %% [markdown]
# ### Printing text with entities

# %%
bcolors = {
    "PESSOA": '\033[94m',
    "TEMPO": '\033[92m',
    "LOCAL": '\033[93m',
    "ORGANIZACAO": '\033[91m',
    "JURISPRUDENCIA": '\033[35m',
    "LEGISLACAO": '\033[36m',
    "ENDC": '\033[0m',
    "O": ""
}

for entities_sentences, sentences in zip(docs_labels[:2], docs_tokenized[:2]):
    for preds, sentence in zip(entities_sentences[:100], sentences[:100]):
        for index, word in enumerate(sentence):
            print(bcolors[preds[index]] +
                word + bcolors["ENDC"], end=' ')
        print()
    print()
# Out:
# UNICO DOC ; 'PRM-JFA-MG _61~L/J , QJ,3 ENV jPRM-JFA-MG .J ! 1 ! LQ. , j _r2 & J3 MINISTÉRIO PÚBLICO ' FEDERAL .PROCURADORIA DA REPÚBLICA NO MUNICÍPIO DE JUIZ DE FORA - MINAS GERAIS Oficio i50iL /2013- MPF/PRM/JF/GAB/OFM Juiz de Fora , 03 de outubro de 2013. l1ustIÍssimo Senhor TRIBUNAL DE CONTAS DA LJI\IIAO ~ SECRETARIA DE CONTROLE EXTERI ' W.MG !
# RUA üAMP , NA '/ERDE , ~~3 ' I José Reinaldo da Motta SALGADO FILHO - CEP : 30550-340 PROTOCOLO Secretário de Controle Externo de Minas Gerais 1 ' I OUT .
# 2013 Tribunal de Contas da União em Minas Gerais BELO HORIZONTE .
# MG Rua Campina Verde , 593 - Salgado Filho HORÁRIO H Hi'ln CEP 30.550-340 Belo Horizonte - MG Assunto : Apresenta representação l1ustIÍssimo Senhor , Com os meus cumprimentos , visando instruir a Notícia de Fato 1.22.001.000236/2013-46 , encaminho a Vossa Senhoria cópia de documentação extraída de seus autos , servindo este oficio de REPRESENTAÇÃO para a instauração , por este TribunaL do devído procedimento para apuração de responsabilidades .
# Atenciosamente , Procurador Regional da República LVC Rua Santo Antônio .
# 990/1501 - Centro - .Juiz de For8 - M ( ; - CEP 36.016.210 Telefones : ( 32 ) 4009.1250 - Fax : ( 32 ) 4009-1280 Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 50664025 .
# ! .
# \ _ MlNIsTÉRIO PúBLICO FEDERAL .
# PROCURADORIA .
# , DA REPúBLICA NO MUNICÍPIO DE JUIZ DE FORA .
# Rua Santo Antônio , 990 - centro - CEP : 36016-210 -Juiz de ForalMG .
# Ao Exmo Sr .
# Or .
# Carlos Bruno Ferreira da Silva Doc fi '' PRM-JFA-MG-00005042/20 13 Senhor Procurador , - Envio a -V. Ex ' o presente documento para verificação da possibilidade de autuação de .Peça Informativa .
# Outrossim , informo que foi realizada pesquisa no sistema'APTUS com os seguintes termos : -RODRIGO DANI ? LI SOUZA , NOS9CôM10 , 0145.1 1.001101-5 , JORNADA .
# Tendo sido localizado os seguintes procedimentos : 1.22.001.000370/2011-82 , 1.22.001.000107/2013- 58 e 1.22.001.00011512013-02 .
# - Juiz de Fora , 19 de agos de 2013 .
# -liNfA MA ( A .
# POS T êc .
# À Ma SU I ' DESPACHO ( ) Arquive-se na PRMlJF , mediante registro no sistema próprio , comunii : :ando-se ao representante que os fatos narrados não configuram lesão aos interesses cuja defesa incUll1l : ! .eao Ministério Público promover , com a advertência dé que desta decisão cabe recurso administrativo á ser interposto nestâ .
# Unidade , no prazo de 10 ( dez ) dias .
# .
# ( ) Arquive-se na PRMlJF , mediante registro no sistema próprio , comul\icando-se ao representante que a narrativa dos fatos nãõ ' contém elementos mínimos capazes de indicar a pertinência ou.a - .
# possibilidade de intervenção do- Minístério Público , com a advertência de que desta-deCisão- càbe recurso administrativo a ser interposto nesta Unidadé , no prazo de 10 ( dez ) dilis .
# ( ) Os fatos narrados não atraem a atribuição desta Unidade do Ministéri ( ; 'Público Federal .
# Após _ autuação como peças de informação , remetam-se a ( 9 ) , para ~ `` providênciás que entender cabíveis .
# Comunique-se ao representante .
# '- ( ) Antes , porem , à ( ) __ CCRI ( ) PFDC , para análise da promoção de declínio de atribuição , conforme fundamentação - abaixo .
# .
# .. , - ( ) Após autuação como peças de informação , submetam-se os autos à ( ) __ CCRI ( ) PFOC , o para análise da_promoção de arquivamento , conforme fundamentação abaixo .. ( ) ~pós autuação como peças de informação , requisite-se à DPF/JF a instauração de inquéri~o policial .
# .
# _ ( X- ) AE9s autuação como oecas de informa ão ? < !
# cíveis/ ( ) criminais , ~istribua-se .
# ( ) :7~CC ! ?
# _.-t ' 7- ~ .
# • tiPAz1'/uP 1ehttCé ?
# Uf=5r `` Juiz de Fora , .tZZ.J o=J / 13 .
# -o '' ' CARLOSBRUNOFERRE AS~VA Procurador da Repúbli a Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código
para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 51893814 .
# Infraero havia sancionado a CBEMI com a penalidade de suspensão de licitar e contratar .
# Com nítido intuito de contratar , a qualquer custo , o Consórcio CCMIÁPIA , o DNIT proferiu nova decisão mantendo a inabilitação da CBEMI ( em verdadeiro descumprimento das liminares ) , embasada em novos fundamentos .
# Com efeito , o DNIT manteve ª inabilitação da CBEMI do RDC Eletrônico no 612/2013 ; sob novos fundamentos de suposta falta de certidão negativa da Justiça do Trabalho ~ uma sanção imposta pela Infraero .
# E contra este novo ATO ILEGAL praticado P.Q ! .
# agentes do DNIT que ª CBEMI propõe ªpresente representação .
# Diante da flagrante ilegalidade do ATO , ~do nítido interesse do DNIT em favorecer o Consórcio CCM/ÁPIA , pede-se o deferimento de medida cautelar , ª fim de anular o ATO que inabilitou novamente ª CBEMI do RDC Eletrônico n ° 612/2013 .
# Com relação à certidão negativa da Justiça do Trabalho , vale dizer que a CBEMI apresentou a referida certidão negativa na data em que houve o deferimento da medida liminar judicial .
# E ainda , nesta data ( 10 I 09 I 2014 ) , a CBEMI possui a certidão trabalhista negativa .
# Ocorre que o DNIT realizou a consulta , em data anterior , e como naquela específica data ( escolhida `` a dedo '' pelo 7 Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 51893814 .
# DNIT ) havia restrição na certidão da Justiça do Trabalho , o DNIT optou por inabilitar a CBEMI , novamente .
# Ora , a certidão negativa da Justiça do Trabalho deve ser aferida na data da apresentação da proposta e na data da assinatura do contrato .
# Trata-se de respeito ao princípio da vinculação ao instrumento convocatório .
# Caso alguma empresa tenha alguma restrição em suas certidões em determinado momento , ainda que resolva o problema num curtíssimo período , algum agente mal intencionado poderá sempre utilizar essa certidão com restrição para prejudicar ( ou beneficiar ) algum licitante .
# É exatamente o que está ocorrendo no caso em exame .
# A CBEMI detinha a certidão negativa da Justiça do Trabalho na dat~ da apresentação de sua proposta no certame , na data do deferimento da liminar , na data em que o contrato deveria ser assinado , e também no momento atual .
# O fato da certidão da Justiça do Trabalho da CBEMI ter apresentado uma restrição , em determinado momento no passado , está sendo utilizado pelos agentes do DNIT para favorecimento do Consórcio CCM/ ÁPIA .
# A penalidade de suspensão de licitar e contratar ~ mencionada no ato ilegal ora impugnado , além de ser objeto de \ 1 8 Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 51893814. discussão em ação própria , limita-se ao âmbito da INFRAERO , não servindo como fundamento para desclassificação do certame promovido pelo DNIT .
# Este assunto será abordado de modo mais abrangente no próximo tópico .
# Por meiO de .
# decisão publicada no D.O.U .
# em 25/08/2014 , afrontando as liminares deferidas no MS n° 0037924- 74.2014.4.01.3400 da 7a Vara Federal do Distrito Federal , declarou vencedor , homologou e adjudicou o objeto da licitação ao Consórcio CCM/ ÁPIA , segundo colocado na licitação .
# de 29/06/2009 , n° 121 , Seção 1 , páginas 54/66 e alterado pela Portaria Normativa no 357/MD , de 5 de março de 2010 .
# OZÓRIO LUCAS FERREIRA DA SILVA Superintendente de Contratos e Convênios Em exercício COORDENAÇÃO DE COMPRAS E INVESTIMENTOS ( Diário Oficial da União ( DOU ) , 29/08/2013 , Seção 3 , pg .
# 11 ) Vê-se que o teor da sanção deixa muito claro que a suspensão/impedimento de licitar e contratar se restringe ao ] , âmbito da Infraero .
# ( ' 11 Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 51893814 .
# Ainda que o teor da penalidade não deixasse claro a restrição de sua extensão apenas ao âmbito da Infraero ( hipótese que se coloca apenas para argumentar ) , a jurisprudência do TCU e a doutrina entendem que a suspensão do direito de licitar e contratar possui efeito restritos ao âmbito da própria instituição que aplicou a penalidade .
# Confira-se o entendimento do próprio Tribunal de Contas da União : `` Representação .
# Responsabilidade .
# A sanção prevista no art .
# 87 , inciso III , da Lei n° 8.666/1993 ( suspensão temporária de participação em licitação e impedimento de contratar com a Administração ) possui seus efeitos restritos ao âmbito da própria instituição que aplicou a penalidade .
# Determinação : [ ... ] [ VOTO ] 4 .
# A questão levantada na presente representação diz respeito a possível irregularidade na desclassificação da licitante pelo órgão , sob o fundamento de que a mencionada empresa estar ia impedida de licitar com toda a Administração Pública , em razão de ter sido anteriormente penalizada pela Agência N acionai de Energia Elétrica ~ ( ANEEL ) , suspendendo- a de licitar e contratar com a~ 12 Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 51893814 .
# Administração pelo período de dois anos , nos termos do art .
# 87 , inciso III , da Lei n° 8.666/1993 .
# [ ... ] 7 .
# Como se pode observar , o TCU fixou entendimento no sentido de que a sanção prevista no art .
# 87 , inciso III , da Lei n° 8.666/1993 ( suspensão temporária de participação em licitação e impedimento de contratar com a Administração ) possui seus efeitos restritos ao âmbito do próprio órgão que cominou a penalidade .
# 8 .
# Assim , diante das conclusões alçadas no supracitado aresto , a Fundação Universidade de Brasília , em sua manifestação nos autos , reconheceu o entendimento deste Tribunal , o que implica em nulidade do ato de desclassificação da licitante '' ( AC-0342-05/14-P , Sessão : 19/02/14 , Relator : Min .

# %% [markdown]
# ## Analysing entities found

# %%
df_sample['PESSOA'] = person_docs
df_sample['TEMPO'] = time_docs
df_sample['LOCAL'] = localizations_docs
df_sample['ORGANIZACAO'] = organizations_docs
df_sample['JURISPRUDENCIA'] = jurisprudence_docs
df_sample['LEGISLACAO'] = legislation_docs

# %%
for tipo in TIPOS_ENTIDADES:
    print("Quantidade de entidades encontradas do tipo: " + tipo + " - " + str(count_entidades[tipo]))

# %%
for column in df_sample.columns:
    print("Entidades do tipo: " + column)
    print(generate_freq_dist_plot(df_sample[column]))
    generate_wordcloud(df_sample[column])

# %% [markdown]
# ### Storing entities found

# %%
"""  Let"s store the data """
excel_filename = RELATIVE_PATH_TO_FOLDER + DATA_FILENAME + "_treated.xlsx"

# %%
"""  Convert the dataframe to an xlsx file """
df_sample.to_excel(excel_filename)

print("Stored tread dataset on ", excel_filename)
