# %% [markdown]
# # AILAB + LeNER-BR
# This jupyter notebook is being develop to integrate the leNER-BR model described in this [article](https://cic.unb.br/~teodecampos/LeNER-Br/luz_etal_propor2018.pdf) with the AILAB text classification pipeline.

# %%
from ailab_ner.lenerbr.ner_model import NERModel
from ailab_ner.lenerbr.config import Config
from ailab_ner.preprocessing import generate_freq_dist_plot, generate_wordcloud
import pandas as pd
from nltk import word_tokenize
from nltk import data
from nltk.tokenize.punkt import PunktSentenceTokenizer
import sys

# %% [markdown]
# ### Constants

# %%
RELATIVE_PATH_TO_FOLDER = "./assets/datasets/"
DATA_FILENAME = "judicial_data"

# %% [markdown]
# ## Loadinging raw data

# %%
excel_filename = RELATIVE_PATH_TO_FOLDER + DATA_FILENAME + ".csv"
df_raw_data = pd.read_csv(excel_filename)

print(df_raw_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 661 entries, 0 to 660
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    661 non-null    int64
#  1   id_documento  661 non-null    int64
#  2   area1         661 non-null    object
#  3   tema1         661 non-null    object
#  4   subtema1      661 non-null    object
#  5   area2         140 non-null    object
#  6   tema2         140 non-null    object
#  7   subtema2      140 non-null    object
#  8   area3         36 non-null     object
#  9   tema3         36 non-null     object
#  10  subtema3      36 non-null     object
#  11  area4         16 non-null     object
#  12  tema4         16 non-null     object
#  13  subtema4      16 non-null     object
#  14  area5         4 non-null      object
#  15  tema5         4 non-null      object
#  16  subtema5      4 non-null      object
#  17  area6         1 non-null      object
#  18  tema6         1 non-null      object
#  19  subtema6      1 non-null      object
#  20  area7         1 non-null      object
#  21  tema7         1 non-null      object
#  22  subtema7      1 non-null      object
#  23  body          661 non-null    object
# dtypes: int64(2), object(22)
# memory usage: 124.1+ KB
# None

# %% [markdown]
# ### Treating data

# %%
df_data = pd.DataFrame(data=df_raw_data['body'])
print(df_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 661 entries, 0 to 660
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   body    661 non-null    object
# dtypes: object(1)
# memory usage: 5.3+ KB
# None

# %% [markdown]
# ### Sampling data

# %%
df_sample = df_data.sample(n=50)
print(df_sample.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 37 to 144
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   body    50 non-null     object
# dtypes: object(1)
# memory usage: 800.0+ bytes
# None

# %% [markdown]
# ### Data Visualization

# %%
print(df_sample.head())
# Out:
#                                                   body
# 37   idente do Egrégio Tribunal de ContilLSI~   EXA...
# 653  www.eiroadvogados.com.br Correspondentes:Brasí...
# 173  1<:  POOER JUOICI,\RIO       FEOERAL JUSTiÇA D...
# 592  Exmo. Sr. Ministro do Tribunal de Contas da Un...
# 481  ~ •.T .. 5 m   •.•...     Et:p' f'i9It CONSTRU...

# %% [markdown]
# ## leNER-BR model

# %%
# create instance of config
config = Config()

# build model
model = NERModel(config)
model.build()
model.restore_session(config.dir_model)

tokenizer = PunktSentenceTokenizer()
# Out:
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:30: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:30: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:110: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:110: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:130: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:130: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:145: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:145: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:150: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:150: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /home/dev/PythonEnviroments/ailab-researching/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# From /home/dev/PythonEnviroments/ailab-researching/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /home/dev/PythonEnviroments/ailab-researching/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# From /home/dev/PythonEnviroments/ailab-researching/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /home/dev/PythonEnviroments/ailab-researching/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# From /home/dev/PythonEnviroments/ailab-researching/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/dev/PythonEnviroments/ailab-researching/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# From /home/dev/PythonEnviroments/ailab-researching/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:161: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:161: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:221: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/ner_model.py:221: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/base_model.py:47: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/base_model.py:47: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
#
# Initializing tf session
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/base_model.py:64: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/base_model.py:64: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/base_model.py:65: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/base_model.py:65: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# WARNING:tensorflow:From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/base_model.py:66: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# From /home/dev/algoritmos/[AILAB]/leNER-Br/ailab_ner/lenerbr/base_model.py:66: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Reloading the latest trained model...
# INFO:tensorflow:Restoring parameters from assets/model_assets/model/prototype_revised/model.weights/
# Restoring parameters from assets/model_assets/model/prototype_revised/model.weights/

# %% [markdown]
# ### Listing entities types and preparing variables

# %%
TIPOS_ENTIDADES = ['PESSOA', 'TEMPO', 'LOCAL', 'ORGANIZACAO', 'JURISPRUDENCIA', 'LEGISLACAO']
entities_docs_per_sentence_per_type = dict()
person_docs, jurisprudence_docs, time_docs = [], [], []
legislation_docs, organizations_docs, localizations_docs = [], [], []
count_entidades = dict()

for tipo in TIPOS_ENTIDADES:
    count_entidades[tipo] = 0

docs = df_sample['body'].values

# %% [markdown]
# ### Using model to identify entities

# %%
tokenizer.train(docs)
docs_labels = []
docs_tokenized = []
for doc in docs:
    entitities_in_doc = dict()
    doc_sentences = tokenizer.tokenize(doc)
    label_doc = []
    for sentence in doc_sentences:
        words = word_tokenize(sentence, language='portuguese')
        preds = model.predict(words)
        label_doc.append(preds)
        for i, word in enumerate(words):
            ''' Removendo sufixo de tipo de entidades'''
            if preds[i][0:2] in ['B-', 'I-', 'E-', 'S-']:
                preds[i] = preds[i][2:]
            if preds[i] != 'O':
                ent_type = preds[i]
                count_entidades[ent_type] += 1
                if ent_type not in entitities_in_doc.keys():
                    entitities_in_doc[ent_type] = [word]
                else:
                    entitities_in_doc[ent_type].append(word)
        
    ''' Separando cada bolsa de palavras por tipo de entididade '''
    if 'PESSOA' in entitities_in_doc.keys():
        person_docs.append(" ".join(entitities_in_doc['PESSOA']))
    else:
        person_docs.append(" ")

    if 'JURISPRUDENCIA'  in entitities_in_doc.keys():
        jurisprudence_docs.append(" ".join(entitities_in_doc['JURISPRUDENCIA']))
    else:
        jurisprudence_docs.append(" ")

    if 'TEMPO' in entitities_in_doc.keys():
        time_docs.append(" ".join(entitities_in_doc['TEMPO']))
    else:
        time_docs.append(" ")

    if 'LEGISLACAO'  in entitities_in_doc.keys():
        legislation_docs.append(" ".join(entitities_in_doc['LEGISLACAO']))
    else:
        legislation_docs.append(" ")

    if 'ORGANIZACAO'  in entitities_in_doc.keys():
        organizations_docs.append(" ".join(entitities_in_doc['ORGANIZACAO']))
    else:
        organizations_docs.append(" ")

    if 'LOCAL'  in entitities_in_doc.keys():
        localizations_docs.append(" ".join(entitities_in_doc['LOCAL']))
    else:
        localizations_docs.append(" ")

    docs_labels.append(label_doc)
    docs_tokenized.append(doc_sentences)

# %% [markdown]
# ### Printing text with entities

# %%
bcolors = {
    "PESSOA": '\033[94m',
    "TEMPO": '\033[92m',
    "LOCAL": '\033[93m',
    "ORGANIZACAO": '\033[91m',
    "JURISPRUDENCIA": '\033[35m',
    "LEGISLACAO": '\033[36m',
    "ENDC": '\033[0m',
    "O": ""
}

for entities_sentences, sentences in zip(docs_labels[:2], docs_tokenized[:2]):
    for preds, sentence in zip(entities_sentences[:100], sentences[:100]):
        words = word_tokenize(sentence, language='portuguese')
        for index, word in enumerate(words):
            print(bcolors[preds[index]] +
                word + bcolors["ENDC"], end=' ')
        print()
    print()
# Out:
# idente do Egrégio Tribunal de ContilLSI~ EXAME PRtvlo DO EDITAL 000452 856361 hs . '
# Ref : Pregão Presenciai n° 01/2011 PROCESSO : N° 159/2010 OBJETO : Contratação de empresa de seguro saúde para prestação de serviços de assistência médico-hospitalar , conforme quantidades e especificações constantes do ANEXO 1- TERMO DE REFERENCIA .
# Fabiana do Nascimento Santana , inscrita no cadastro de pessoa fisica sob o CPF n0228.481.638-01 , estudante do ensino superior , portadora da cédula de identidade RG n ' 40.823.863-5 , residência na Rua Nova 8rasllia n0572 , Jardim Grimaldi - CEP : 03924-040 , vem respeitosamente , á elevada presença de Vossa Senhoria , com fundamento no parágrafo l ' do artigo 113 da lei 6666/93 , ingressar com a presente REPRESENTACAo COM PEDIDO DE LIMINAR , em face do edital do Pregão 0112011 , processo 15912010 do CEAGESP- Companhia de Entrepostos e Armazéns Gerais de São Paulo , pelas razões de fato e de direito a seguir aduzidas .
# DO OBJETIVO Afastar do presente procedimento licitatório , exigência feita em extrapolação ao disposto no estatuto que disciplina o instituto das licitações , desrespeitando inclusive decisãoes consolidadas deste Egregio Corte de Contas .
# Evitar que ocorra restricão desnecessária do universo de possíveis e capacitados competidores , obstando a BUSCA DA CONTRATACAo MAIS VANTAJOSA .
# DOS MOnvOS Registre-se de plano , que no ramo de Assistência Medica Hospitalar , existem centenas de empresas especializadas e detentoras de total e irrestrita capacidade estrutural e operacional para oferecer as cobarturas necessárias solicitadas no edital em referencia e amparadas pelo órgão regulador do setor - Agencia Nacional de Saúde .
# Contudo , ao passo que no presente edital traz consigo exigências comprometedoms , a Administracão fica inviabilizada de analisar uma oferta extremamente vantaiosa , impossibilitando mais de 90 % das empresas que operam planos de assistência á saúde participem do certame .
# Com efeito , o exame acurado do edital revela situação que merece urgente reparo por autoridade , pois cria óbice à própria realização da disputa , limitando o leque da licitacão a apenas um grupo seleto do segmento ( seguradoras ) e ainda tratando desigualmente os iguais .
# Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 45578159. , Inclusive , não é demais lembrar que a própria lei n.· 8.666/93 está carregada de tópicos de preocupação , acerca da responsabilização de eventuais responsáveis da disputa por : a ) imposição de restrições indevidas à ampla concorrência ; b ) elaboração imprecisa de editais e c ) inclusão de cláusulas que denotam o direcionamento do procedimento licitatório .
# DOS FATOS o exame acurado do edital revela que , não obstante o CEAGESP - Companhia de Entrepostos e Armazéns Gerais de São Paulo , tenha se apoiado em requisitos usuais do mercado para garantir uma aquisição direcionada à `` Contratação de serviço de assistência médica hospftalar '' , veio inserir no rol de especificações das condições de participação , exigência incompatlvel com os próprios limites impostos pela 8.666/93 - o que acaso não revista certamente cerceará o direfto de participação de mais de 90 % das empresas interessados .
# Trata-se da exigência especificada no subftem 5.1.1 do edftal que determina que , para fins de participação do certame , as licitantes deverão obrigatoriamente serem regidas Pelas normas do Conselho Nacional de Seguros Privados - CNSP e da Superintendencia de Seguros Privados - SUSEP .
# Abaixo transcrição do item 5.1.1 5 - DAS CONDlcOES DE PARTlCIPAcAO 5.1.1.Somente poderao participar desta licitaçao as empresas brasileiras ou estrangeiras em funcionamento no Brasil , pertencentes ao ramo do objeto licitado .
# sendo vedada a partlcipaçêo de consórcios , empresas com falência decretada , concordatárias , declaradas inidOneas para licitar ou contratar com a Administração Pública ou com suspensão do direito de licitar e contratar com a CEAGESP .
# As empresas participantes deveria reger-se pelas nonnas do Conselho Nacional de Seguros Privados - CNSP , da SUSEP , e serem registradas ou autorizadas na ANS Em outras palavras , os participantes do certame alem de estarem registradas no órgão regulamentador ANS - Agencia Nacional de Saúde , deverão ser registrados na SUSEP e CNSP , condição esta , completamente Ilegal , pois quem rege e fiscaliza as Normas do Setor de Saúde Privado é a Agencia Nacional de Saúde .
# Ocorre que para operar planos de saúde privados no Brasil , não é necessário que a empresa seja uma seguradora , pois na definição da Agencia Nacional de Saúde as empresas e entidades que atuam no setor de saúde suplementar , são chamadas operadoras de plano de assistência a saúde e classificadas pela ANS em 8 ( afto ) modalidades , são elas : administradoras .
# cooperativas médicas .
# cooperativas odontológicas , instituições filantrópicas , au ! t. > gest6es ( patrocinadas e não patrocinadas ) , seguradoras especializadas em saúde , medicina de grupo e odontologia de grupo .
# Contudo em que pese o reconhecimento da referida exigência ( registro SUSEP e CNSP ) ser ilegal para fins de sustentabilidade em aspectos relacionados á legislação que regulamenta o setor de saúde Oei 9656-96 ) e em especial com o art .
# 3° , § 1° , inciso I da lei n° 8.666/93 , fato é que : • A homotogaçAo de qualquer serviço referente plano de assistência a saúde nao oode estar liaada a uma entidade Que nAo é reoulamentadora do setor .
# Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 45578159. , ·o governo brasileiro nao torna obrigatória que uma operadoras de plano de assistência a saúde seja certificada pelo Conselho Nacional de Seguros Privados - CNSP e pela Superintendencia de Seguros Privados - SUSEP .
# • O fato de uma operadoras de plano de assistência a saúde nao estar Registrada na SUSEP e CNSP , não dá azo a afirmar que seus serviços nao tem qualidade , ou até mesmo que não poderá oferecer as coberturas especificadas no edital , mas apenas ressalta o fato de tal operadora nao é uma seguradora , pois para operar planos de saúde não é necessário ser seguradora .
# • Na Agencia Nacional de Saúde existem 1690 ( um mil , seiscentos e noventa ) operadoras de saúde ativas , porem com a exigência de operar tambem no ramo de Seguros , no maximo 02 empresas comparecerão no certame - o que configura notório direcionamento .
# A potencialidade de restrição empregada ao subitem 5.1.1 , se toma verdadeiramente presente quando analisado em conjunto com todos os requis~os técnicos mlnimos bazidos no termo de referência - Anexo I - do ed~al , demonstrando que , mu~o embora o Administrador revele em seu preâmbulo , se tratar de licitação para aquisição de Serviços de Assistência Medica á seus funcionário e dependentes , há indlcios firmes já na descrição do objeto a ser contratado que o certame está favorecendo um único conjunto de empresas , ou senão uma única empresa .
# Ora , uma leitura rasa do conjunto de elementos exigidos no Anexo I do edital revela que qualquer operadora do ramo poderia atender aquelas especificações , porem ao exigir que a operadora de saúde seja também uma seguradora é notório o direcionamento para a atual contratada .
# Assim , obrigar que as empresas participantes tenham registro como seguradoras , força o entendimento que o CEAGESP - Companhia de Entrepostos e Armazéns Gerais de São Paulo de fato está à procura de uma única empresa , o que toma evidente o favorecimento .
# De todo modo , é óbvio que tal exigência terá por efeito inarredável eliminar < ! 9~certame um largo conjunto de empresas altamente capaci1adas .
# sobretudo quando _c '' ; - , _- .
# ! .~ , - , .__ , - .
# ' c ' '' . , .
# d ; · ; -c~·· : '' ' c '' -~_- ' , .. !
# ~ '' . `` ..
# `` ; , ~_ ~-_~ '' , ~ !
# ; '' J. frsta cl1sputa por si sÓ % são suficientes a diminuir o espectro competitivo do certame .
# E tal conduta certamente não se coaduna com os princljJlOS básicos das licitações , contidos no Art .
# 37 , XXI , da Constituição Federal e no Art .
# 3° da Lei das Licitações , tais como os da legalidade , impessoalidade , moralidade , igualdade , probidade administrativa , e seleção da proposta mais vantajosa .
# E infere.5e , ainda , do artigo 3° , que é vedado à Administração ultrapassar esses fimites , por meio da irn : lusâo de condições que restrinjam a participação no procedimento ou que maculem a isonomia e igualdade entre as licitantes .
# verbís : Art .
# 3.Q ... .A licitação destina-se a garantir a observância do princfplo constitudonal da isonomia e a selecionar a proposta mais vantajosa para a Administração e será processada e juJgada em estrita conformidade com os prlnápios bâslcos da IegaDtlade .
# da impessoalidade , da moralldade , da igualdade , da publicidade , da probidade administrativa , da vinculação ao instrumento convocat6rlo , do julgamento objetivo e dos que lhes são correlatos .
# § 10 Evedado aos agentes públicos : · ... ... .. ~ - ' ••.••• .
# '- ... ... ... . _ •••••• .I .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# • 01 .
# .
# .
# .
# . '
# • • • ... ... ... .. Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 45578159 .
# • preferências ou distinc§es em fatio da naturnlldade .
# da sede ou domidllo dos licitantes ou de qualquer outra drçunstincla Impertinente ou Irrelevante para o espedflco ohleto do contratoi 11 - estabelecer tratamento diferenciado de natureza comercial , legal , trabalhista .
# previdenciária ou qualquer outra , entre empresas brasileiras e estrangeiras , inclusive no que se refere a moeda , modalidade e local de pagamentos , mesmo quando envolvidos financiamentos de agências Internadonals .
# ressalvado o disposto no parágrafo seguinte e no 3rt .
# 30 da lei no 8.248. de 23 de outubro de 1991 .
# FAVORECIMENTO E DIRECIONAMENTO A conjugação de todas as circunstancias acima arroladas toma indiscutlvel a averiguação de que a OBRIGATORIEDADE de somente poderem participar do certame as operadoras de saúde classificadas na modalidade de seguradora , foge do real atendimento às necessidades a que se destina o objeto da licitação , e configura , na realidade , disfarce ao caráler competilivo da disputa .
# No presente caso , a delimitação velada por meio de descrição tendenciosa e minuciosa dos requisitos exigiveis .
# Pela constatação que a contratação de serviços de assistência médica pode ser oferecida em igualdade dentro das varias modalidade de classificação aferidas pela ANS , configura excesso de dimensionamento de exigências , destinada a um grupo exclusivo do mercado ( seguradoras ) , senão a uma única empresa , assim sendo o presente edital merece urgente reforma , sob pena de comprometimento total da disputa .
# CONCLUSÃO Isto posto , Excelência , resta evidente que o presente instrumento convocatória carece de reparos , sobe pena de prejudicar seu fundamento principal , qual seja , a realização da disputa publica .
# Ao estabelecer em suas exigência que a operadora de planos de saúde seja cadastrada como seguradora , acaba por favorecer sem sombra de duvidas a atual prestadora de serviços .
# DO PEDIDO Por todo o alegado , aguarda e confia o representante , que , em razllo das irregularidades apontadas a Vossa Excelência , seja determinada a suspensão do referido processo licitatorio liminarmente até a decisão final da presente representação , tendo em vista que , á abertura e a entrega dos envelopes será no dia 15 de março de 2011 e que há claramente ilegalidade flagrante e prejufzo aos participantes .
# Ao final , requer seja a presente julgada procedente , de modo a determinarão CEAGESP - Companhia de Entrepostos e Armazéns Gerais de São Paulo , a retificação dos itens ilegais identificados , sob as penas da lei .
# ~~ento Santana Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 45578159 .
#
# www.eiroadvogados.com.br Correspondentes : Brasília- São Paulo EXMO .
# SR .
# MINISTRO PRESIDENTE DO TRIBUNAL DE CONTAS DA UNIÃO - ESTADO DO PARÁ .
# TClI-seCEX-PA RECEBJDO E'OJ1IQ , Y.. ! i ) -Jef~W ?
# ÂNGULO FORTE CONSTRUÇÕES E PROJETOS l TOA • EPP , pessoa jurídica de direito privado , inscrita no CNPJ sob o n° 05.848.749/0001-07 , estabelecida na Avenida T-10 , esquina com a Rua T-27 , nO208 , quadra 102 , Us .
# : 09/12 , 25° andar , Ed .
# New Times Square Urban Oflice , Setor Bueno , CEP 74.223-060 , em Goiânia-Goiás , fulcrada no Art .
# 71 , V , VI , VIII , IX e XI , 3 1° , 3 2° e 3 3° da Constituiçâo Federal de 1988 , Art .
# 113,31° da lei 8666/93 , c/c o Art .
# 237 , VII do Regimento Interno do Tribunal de Contas da União , vem mui respeitosamente , á presença de Vossa Excelência interpor REPRESENTAÇÃO em desfavor do SEBRAE/PA - SERViÇO BRASilEIRO DE APOIO ÀS MICRO E PEQUENAS EMPRESAS , pessoa juridica de direito privado , inscrita no CNPJ sob o nO05.081.187/0001- 19 , com sede na Rua Municipalidade , 1461 , Bairro do Umarizal , CEP 66.050-350 , em Belém-Pará , pelos fatos , fundamentos jurídicos e circunstâncias a seguir expostos : , I . DOS FATOS : 1 .
# A Representante inscreveu-se no CERTAME LICITA TÓRIO 04/2017 aberto pelo Representado , para a contratação de empresa de ENGENHARIA PARA A EXECUÇÃO DA REFORMA DO BLOCO RMB DA SEDE DO SEBRAE PARÁ , com valor de referência para a obra no montante de R $ 13.808.732,42 ( treze milhões , oitocentos e oito setecentos e trinta e dois reais e quarenta e dois centavos ) , cuja abertura da licitação ocorreu em 07/08/2017 .
# 2 .
# Conforme documentação em anexo , a Representante foi HABILITADA EM TODAS AS FASES DO CERTAME , uma vez que APRESENTOU TODAS AS DOCUMENTAÇÕES NECESSÁRIAS , demonstrou possuir SOLVÊNCIA FINANCEIRA e PATRIMONIAL , além de ter apresentado a MELHOR e MAIS BARATA PROPOSTA para a execução do contrato , uma vez que a Representante apresentou o preço de R $ 10.650.004,01 ( Dez Milhões , Seiscentos e Cinquenta Mil , Quatro Reais e Um Centavo ) e , conforme ' . '' ''
# Página 1 de 15 li .~l ! J Av .
# Almirante Wandenkolk , 266 - Umarizal li : ~ .
# ' 7 ' : CEPo66.055-030 - Belém - Pará - Brasil .
# .
# Fone/Fax : + 55 91 3223-4466 - 3242-86 3 ... , . , .
# .
# .
# ..
# E-mai !
# : marcoseiro @ gmail.com Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 58637287. www.eiroadvogados.com.br Correspondentes : Brasília .
# São Paulo o EDITAL , trata-se de uma CONCORRÊNCIA por MENOR PREÇO GLOBAL do serviço contratado , o que foi devidamente cumprido pela Representante .
# 3 .
# Tanto é verdade que quando do JULGAMENTO HABILITAÇÃO , ocorrido em 05/10/2017 , em sua página final ( 26 ) a COMISSÃO DE LICITAÇÃO HABILITOU A REPRESENTANTE PARA CONTINUAR NO CERTAME , já que CUMPRIU TODAS AS EXIGÊNCIAS DO EDITAL .
# Todavia , para a surpresa da Representante , eis que no dia 22/11/2017 , quando do JULGAMENTO DAS PROPOSTAS DE PREÇOS , eis que o Representado , através da Comissão de Licitação , alegou no referido documento ( cópia em anexo ) que na planilha apresentada pela Representante haviam itens com valores abaixo dos valores de referência , preços diferentes de um mesmo serviço e FALTA DE COMPOSiÇÃO DO PREÇO UNITÁRIO NO ITEM 10.5 DA PLANILHA entregue á COMISSÃO DE LICITAÇÃO do Representado ( em anexo ) .
# 4 .
# Vale ressaltar que o item que a Comissão do Representado se referiu é UM RODAPÉ EM GRANITO PRETO TIJUCA POLIDO H = 15 em ( quinze eentimetros ) , o qual possui como preço o valor de R $ 29.049,99 ( VINTE E NOVE MIL , QUARENTA E NOVE REAIS E NOVENTA E NOVE CENTAVOS ) , o que NÃO CHEGA A 0,50 % ( MEIO POR CENTO ) DO VALOR DA PROPOSTA DA REPRESENTANTE , que foi de R $ 10.650.004,01 ( Dez Milhões , Seiscentos e Cinquenta Mil , Quatro Reais e Um Centavo ) , sendo a MELHOR PROPOSTA e MAIS VANTAJOSA apresentada entre os Licitantes , além do que na planilha enviada por e-mail á Comissão denominada ORÇAMENTO SEBRAE RMB o preço e quantidade do referido rodapé estão devidamente discriminados , sanando assim este erro mínimo , o que jamais poderia ser motivo de desclassificação da Representante , tudo conforme documentos em anexo .
# 5 .
# É imperioso mencionar que a OMISSÃO DE ITENS OU VALORES é motivo de DESCLASSIFICAÇÃO DESDE QUE SE TRATE DE PARTE CONSIDERADA ESSENCIAL PELA COMISSÃO DE LICITAÇÃO , conforme cláusula 8.1.1.4 do Edital de Concorrência , o que jamais é o caso do item descrito acima , além do fato de que a Representante FOI CONSIDERADA HABILITADA EM TODAS AS FASES ANTERIORES , JAMAIS SENDO MENCIONADA TAIS QUESTÕES , NEM MESMO PELAS OUTRAS LICITANTES , dada a INSIGNIFICÃNCIA do item em debate .
# 6 .
# Além disso durante as fases do processo , percebeu-se claramente que o primeiro Representado , na figura da Comissão de Licitação foi extremamente complacente com as empresas denominadas SANECON - SANEAMENTO E CONSTRUÇÃO CIVIL - EIRELI ( que ficou em primeiro lugar com a desclassificação da proposta da Representante e foi DECLARADA VENCEDORA DO CERTAME ) e LACA ENGENHARIA L TDA - EPP ( que ficou em segundo lugar com a desclassificação da proposta da ... .. : ' Representante ) , já que , conform documento denominado JULGAMENTO HABILITAÇÃO ( em anexo ) , Página 2 de 15 11 .l ! l Av .
# Almirante Wandenkolk , 266 - Umarizal : .
# ..'~ .
# CEP : 66.055-030 - Belém - Pará - Brasil .
# - .
# Fone/Fax : + 55 91 3223-4466 - 3242-869 l ! l . '
# '. , E-mail : marcoseiro @ gmail.com Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 58637287. www.eiroadvogados.com.br Correspondentes : Brasília- São Paulo ocorrido em 05/10/2017 a própria COMISSÃO DE LICITAÇÃO ATESTOU VÁRIAS ILEGALIDADES DAS DUAS EMPRESAS ACIMA CITADAS e , ainda assim MANTEVE-AS HABILITADAS E CLASSIFICADAS NO CERTAME , DO QUAL A SANECON FOI DECLARADA VENCEDORA DO CERTAME DE FORMA COMPLETAMENTE ILEGAL E AINDA COM A HOMOLOGAÇÃO DO CERTAME EM PLENO RECESSO DO SEBRAE/PA , conforme documento em anexo .
# 7 .
# Basta observar o ITEM 2 ( dois ) da página 19 ( dezenove ) do supracitado documento ( em anexo ) , onde consta que a empresa VENCEDORA DO CERTAME , a SANECON APRESENTOU DIFERENÇA ENTRE O ATIVO E O PASSIVO DE R $ 0,01 ( UM CENTAVO DE REAL ) , com íNDICE BEM ABAIXO DA REPRESENTANTE , PORÉM SURPREENDENTEMENTE HABILITADA , CLASSIFICADA e VENCEDORA DA LICITAÇÃO .
# B . Menos `` sorte '' ainda obteve a LACA ENGENHARIA L TOA - EPP , que acabou ficando em segundo lugar no certame , já que a própria COMISSÃO DE LICITAÇÃO DO REPRESENTADO RECONHECEU que a referida empresa no ano de 2016 teve Receita de pouco mais de R $ 207.273,02 ( DUZENTOS E SETE MIL , DUZENTOS E SETENTA E TRÊS REAIS E DOIS CENTAVOS ) e DESPESA/CUSTO no valor de R $ 2.164.328,46 ( DOIS MILHÕES , CENTO E SESSENTA E QUATRO MIL , TREZENTOS E VINTE E OITO REAIS E QUARENTA E SEIS CENTAVOS ) gerando um PREJuízo de R $ 1.980.705,25 ( HUM MILHÃO , NOVECENTOS E OITENTA MIL , SETECENTOS E CINCO REAIS E VINTE E CINCO CENTAVOS ) , PORÉM SURPREENDENTEMENTE HABILITADA , CLASSIFICADA E AINDA FICOU EM SEGUNDO LUGAR NA LICITAÇÃO .
# 9 .
# A simples análise das ILEGALIDADES FLAGRANTES acima já é mais do que suficiente para a DESCLASSIFICAÇÃO das DUAS EMPRESAS acima mencionadas , sem contar que a empresa SANECON , que foi DECLARADA VENCEDORA do certame apresentou proposta de R $ 11.164.896,23 ( ONZE MILHÕES , CENTO E SESSENTA E QUATRO MIL , OITOCENTOS E NOVENTA E SEIS REAIS E VINTE E TRÊS CENTAVOS ) , sendo a proposta da Representante R $ 514.892,20 ( QUINHENTOS E CATORZE MIL , OITOCENTOS E NOVENTA E DOIS REAIS E VINTE CENTAVOS ) MAIS BARATA QUE UMA EMPRESA QUE POSSUI R $ 0,01 ( UM CENTAVO DE REAL ) DE LUCRO , NÃO POSSUI SOLVÊNCIA PATRIMONIAL e ainda assim FOI DECLARADA VENCEDORA DO CERTAME , além empresa LACA ENGENHARIA , que somente em 2016 amargou um PREjuízo de R $ 1.980.705,25 ( HUM MILHÃO , NOVECENTOS E OITENTA MIL , SETECENTOS E CINCO REAIS E VINTE E CINCO CENTAVOS ) , circunstâncias que por si só já levariam a DESCLASSIFICAÇÃO das referidas empresas , as quais de forma ILEGAL foram HABILITADAS e CLASSIFICADAS no referido certame , sendo que a SANECON foi DECLARADA V CEDORA e está na iminência de ASSINAR CONTRATO COM O Página 3 de 15 Av .
# Almirante Wandenkolk , 266 - Umarizal CEP : 66.055-030 - Belém - Pará - Brasil Fone/Fax : + 55 91 3223-4466 - 3242-869 E-mail : marcoseiro @ gmail.com Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 58637287. www.eiroadvogados.com.br Correspondentes : Brasilia• São Paulo SEBRAE/PA ( PRIMEIRO RÉU ) , tudo devido á FORMA ILEGAL E ARBITRÁRIA como o Representado conduziu a referida Licitação .
# 10 .
# A Representante apresentou SOLIDEZ FINANCEIRA e PATRIMONIAL , encaminhou a MELHOR PROPOSTA á Comissão de Licitação do primeiro Representado , já que se trata de uma CONCORRÊNCIA DE MENOR PREÇO GLOBAL e , ainda assim , numa obra orçada em R $ 10.650.004,01 ( Dez Milhões , Seiscentos e Cinquenta Mil , Quatro Reais e Um Centavo ) , a Representante ESTÁ SENDO VIOLADA EM SEU DIREITOCRISTALlNO DE VENCER A LICITAÇÃO POR UMA OMISSÃO SANÁVEL DE UM PREÇO DE UM RODAPÉ DE GRANITO , QUE NÃO VALE SEQUER R $ 30.000,00 ( TRINTA MIL REAIS ) , valor que não corresponde nem a 1 % ( um por cento ) do valor da obra , sem contar a REGULARIDADE DOCUMENTAL , FISCAL , PREVIDENCIÁRIA e CAPACIDADE TÉCNICA E LOGíSTICA PROVADAS PELA REPRESENTANTE , que não pode sofrer tal VIOLÊNCIA ILEGAL por conta do Ato Lesivo praticado pelo Representado .
# 11 .
# A própria Comissão de Licitação do SEBRAE/PA , ao analisar a documentação em fase JULGAMENTO DE HABILITAÇÃO da Empresa supostamente que teve a Homologação e Adjudicação na `` calada da noite '' , sintetizou sua capacidade financeira ( vide fls 20i21 ) para gerir uma obra de Grande Vulto , cujo seu preço foi superior ao da Autora em MAIS DE MEIO MILHÃO DE REAIS , senão vejamos : `` 11 - SANECON - SANEAMENTO E CONSTRUÇÃO CIVIL L TOA - Total do ATIVO E PASSIVO com diferença de 0,01 ... .. `` 12 .
# Além de todo o exposto acima , causa enorme espanto , conforme documento em anexo , que o presente certame tenha sido HOMOLOGADO e ADJUDICADO á empresa acima descrita EM PLENO RECESSO NACIONAL DO SEBRAE , sendo assinada em 21/12/2017 pelo DIRETOR SUPERINTENDENTE e pelo DIRETOR ADMINISTRA TlVO FINANCEIRO , CONVOCANDO A `` VENCEDORA '' PARA ASSINAR O CONTRATO A PARTIR DO DIA 02/01/2018 , o que está na iminência de causar um PREJuízo INCALCULÁVEL e IRREPARÁVEL á Representante , que foi a VERDADEIRA VENCEDORA DO CERTAME e foi DESCLASSIFICADA INJUSTAMENTE e ILEGALMENTE pelo Representado .
# 11 - DO DIREITO : 13 .
# A pretensão da Representante encontra abrigo legal na Carta Magna de 1988 , senão vejamos : Página 4 de 15 Av .
# Almirante Wandenkolk , 266 - Umariza CEP : 66.055-030 - Belém - Pará - Brasil Fone/Fax : + 55 91 3223-4466 - 3242-8 3 E-mail : marcoseiro @ gmail.com Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 58637287. www.eiroadvogados.com.br Correspondentes : Brasília- São Paulo Art .
# 71 .
# O controle externo , a cargo do Congresso Nacional , será exercido com o auxilio do Tribunal de Contas da União , ao qual compete : V. fiscalizar as contas nacionais das empresas supranacionais de cujo capital social a União participe , de forma direta ou indireta , nos termos do tratado constitutivo ; VI • fiscalizar a aplicação de quaisquer recursos repassados pela União mediante convênio , acordo , ajuste ou outros instrumentos congêneres , a Estado , ao Distrito Federal ou a Municipio ; VIII - aplicar aos responsáveis , em caso de ilegalidade de despesa ou irregularidade de contas , as sanções previstas em lei , que estabelecerá , entre outras cominações , multa proporcional ao dano causado ao erário ; IX • assinar prazo para que o órgão ou entidade adote as providências necessárias ao exato cumprimento da lei , se verificada ilegalidade ; XI .
# representar ao Poder competente sobre irregularidades ou abusos apurados .
# S 1° No caso de contrato , o ato de sustação será adotado diretamente pelo Congresso Nacional , que solicitará , de imediato , ao Poder Executivo as medidas cabiveis .
# S 2° Se o Congresso Nacional ou o Poder Executivo , no prazo de noventa dias , não efetivar as medidas previstas no parágrafo anterior , o Tribunal decidirá a respeito .
# S 3° As decisões do Tribunal de que resulte imputação de débito ou multa terão eficácia de titulo executivo .
# 14 .
# Além do exposto acima , a Lei 8.666/93 também alicerça o pleito da Representante , a citar : Art .
# 113 .
# O controle das despesas decorrentes dos contratos e demais instrumentos regidos por esta Lei será feito pelo Tribunal de Contas competente , na forma da legislação pertinente , ficando os órgãos interessados da Administração responsáveis pela demonstração da legalidade e regularidade da despesa e execução , nos termos da Constituição e sem prejuizo do sistema de controle interno nela previsto .
# S 12 Qualquer licitante , contratado ou pessoa física ou juridica poderá representar ao Tribunal de Contas ou aos órgãos integrantes do sistema de controle interno ... .. contra irregularidades na aplicação desta Lei , para os fins do disposto neste artigo .
# l ! J 11 ~ .
# I .~ Av .
# Almirante Wandenkolk .
# 266 - Umari I li : , . ' .
# : CEP : 66.055-030 - Belém - Pará - Bras , .
# .
# Fone/Fax : + 55 91 3223-4466.3242.8 I ! l .. .. ' E-mail : marcoseiro @ gmail.com Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 58637287. www.eiroadvogados.com.br Correspondentes : Brasília- São Paulo 15 .
# A LICITAÇÃO DEVE ATENDER AO INTERESSE PÚBLICO e a REPRESENTANTE OBTEVE MELHOR TÉCNICA E MELHOR PREÇO , possuindo solvência patrimonial , projeto e capacidade técnica plena e muito acima de qualquer das licitantes que participaram do Certame , além de ter um índice de endividamento mínimo , o que também foi considerado pelo próprio Representado .
# Além disso , a Representante também apresentou melhor preço em relação às demais empresas participantes do processo de licitação , as quais apresentaram preço superior , o que importarà em um dispêndio de gastos maior e , conseqüentemente , em prejuizo direto e/ou indireto ao Erário Público da União .
# 16 .
# Dessa forma , ao deixar de considerar tal fato , o Representado està violando os principios da Razoabilidade , da Proporcionalidade , da Ampla Competição e da Supremacia do Interesse Público e , ainda em flagrante afronta ao Ordenamento Jurídico que dispõe da matéria , Lei 8.666/93 , repetido na própria Resolução do SEBRAE/PA e que aduz : `` Ar ! .
# 3 ' .
# A licitação destina-se a garantir a observãncia do principio constitucional da isonomia e a selecionar a proposta mais vantajosa para a Administração e será processada e julgada em estrita conformidade com os principios básicos da legalidade , da impessoalidade , da moralidade , da igualdade , da publicidade , da probidade administrativa , da vinculação ao instrumento convocatário , do julgamento objetivo e dos que lhe são correlatos .
# 17 .
# Além disso , a Representante PASSOU POR TODAS AS FASES DA LICITAÇÃO , em fiel cumprimento ao Art .
# 27 da Lei de Licitações , possuindo regularidade fiscal , trabalhista , económica , bem como TODOS OS CERTIFICADOS TÉCNICOS que atestam sua SUPERIOR CAPACIDADE para executar a obra objeto do Edital , bem como ser a VENCEDORA DO CERTAME que foi HOMOLOGADO EM FAVOR DA SANECON de forma COMPLETAMENTE ILEGAL , além do que a ELIMINAÇÃO DA REPRESENTANTE ocorreu de forma ABSURDA , ao completo ARREPIO DA LEI , não podendo este Nobre Tribunal silenciar diante de flagrante INJUSTiÇA em desfavor da Representante .
# 18 .
# A presente representação é o meio legal posto à disposição da Representante , haja vista a ILEGALIDADE de sua ELIMINAÇÃO do certame , bem como o RISCO DE LESÃO IREPERÁVEL em caso de ASSINATURA DO CONTRATO PELA EMPRESA SANECON - SANEAMENTO E CONSTRUÇÃO C/V/L - E/RELI , uma vez que a Representante é a VERDADEIRA VENCEDORA DO CERTAME , pois apresentou a MELHOR PROPOSTA e CAPACIDADE TÉCNICA , SOLVÊNCIA Páoj Av .
# Almirante Wandenkolk .
# 266 - Umariz CEP : 66.055-030 - Belém - Pará - Brasil Fone/Fax : + 55 91 3223-4466 - 3242-86 3 E-mai !
# : marcoseiro @ gmail.com Para verificar as assinaturas , acesse www.tcu.gov.br/autenticidade , informando o código 58637287. www.eiroadvogados.com.br Correspondentes : Brasília- São Paulo PATRIMONIAL e CUMPRIMENTO DE TODAS AS FASES DO CERTAME , não podendo ser DESCLASSIFICADA DE FORMA ILEGAL por um ATO ABUSIVO e ILEGAL do Representado .
# 19 .
# A presente representação tem por escopo antecipar-se á ocorrência da violação irreparável do direito da Representante e conferindo real efetividade á tutela do Tribunal de Contas , cujo provimento pleiteado ( SUSPENSÃO DO CERTAME e da ASSINATURA DO CONTRATO ) deve ser DEFERIDO PELA AUTORIDADE deste Tribunal , ainda mais no caso da Representante , que FOI ELIMINADA DO CERTAME , o qual ainda foi HOMOLOGADO á Pessoa Juridica INCAPAZ FINANCEIRAMENTE e com CAPACIDADE TÉCNICA duvidosa , o que é um risco enorme ao erário público da União , ente público a que se vincula o SEBRAEIPA , ora Representado .
# 20 .
# Além disso a Representante teve a MELHOR PROPOSTA , já que se trata de uma LICITAÇÃO DE MENOR PREÇO GLOBAL , conforme o Edital , o que por si só já VIOLA o artigo 3° da Lei Federal N° 8.666/93 , que trata da selecão da proposta mais vantajosa para o poder público .
# 21 .
# A Licitação constitui-se no procedimento administrativo mediante o qual a Administração Pública seleciona a proposta mais vantajosa para o contrato de interesse público , desenvolvendo-se através de sucessões ordenadas de atos vinculantes para a Administração e para os licitantes .
# Tanto que , o próprio REGULAMENTO DO SEBRAE para Licitações e Contrato consagra em seu Art .
# 2° o destino e objetivo da Licitação pelo Sistema Sebrae pela PROPOSTA MAIS VANTAJOSA , o que NÃO EXPLICA O REPRESENTADO ESCOLHER COMO VENCEDORA UMA PROPOSTA R $ 514.892,20 ( QUINHENTOS E CATORZE MIL , OITOCENTOS E NOVENTA E DOIS REAIS E VINTE CENTAVOS ) MAIS CARA E DISPENDIOSA QUE A DA REPRESENTANTE e , AINDA HOMOLOGAR E ADJUDICAR À LICITAÇÃO EM PLENO RECESSO NACIONAL DO SEBRAE , conforme DOCUMENTO EM ANEXO .
# 22 .
# O Edital da Concorrência em debate não pode se dissociar do REGULAMENTO DAS LICITAÇÕES E CONTRATOS DO REPRESENTADO , que tem por objetivo a CONTRATAÇÃO DA PROPOSTA MAIS VANTAJOSA , além do que a Representante FOI APROVADA EM TODAS AS FASES e considerada HABILITADA , sendo DESCLASSIFICADA e ELIMINADA de forma ILEGAL , assim como a HOMOLOGAÇÃO em favor da empresa SANECON - SANEAMENTO E CONSTRUÇÃO CIVIL - EIRELI , que se encontra na iminência de ASSINAR o contrato objeto da Licitação , o que trará á Representante PREJUjZOS IRREPARÁVEIS , pois os atos praticados pelo Representado macularam o DIREITO CRISTALINO e INDUBITÁVEL da Representante , bem como GRAVE e LITERAL VIOLAÇÃO ' . '
# . '
# aos principios da Razoabilidade , da Proporcionalidade , da Ampla Competição e da Supremacia Pá ina7deJS 11 .l ! l Av .
# Almirante Wandenkolk , 266 - Umarizal - .
# I li .
# .

# %% [markdown]
# ## Analysing entities found

# %%
df_sample['PESSOA'] = person_docs
df_sample['TEMPO'] = time_docs
df_sample['LOCAL'] = localizations_docs
df_sample['ORGANIZACAO'] = organizations_docs
df_sample['JURISPRUDENCIA'] = jurisprudence_docs
df_sample['LEGISLACAO'] = legislation_docs

# %%
for tipo in TIPOS_ENTIDADES:
    print("Quantidade de entidades encontradas do tipo: " + tipo + " - " + str(count_entidades[tipo]))
# Out:
# Quantidade de entidades encontradas do tipo: PESSOA - 12385
# Quantidade de entidades encontradas do tipo: TEMPO - 21485
# Quantidade de entidades encontradas do tipo: LOCAL - 14015
# Quantidade de entidades encontradas do tipo: ORGANIZACAO - 45884
# Quantidade de entidades encontradas do tipo: JURISPRUDENCIA - 2514
# Quantidade de entidades encontradas do tipo: LEGISLACAO - 33576

# %%
for column in df_sample.columns:
    print("Entidades do tipo: " + column)
    print(generate_freq_dist_plot(df_sample[column]))
    generate_wordcloud(df_sample[column])
# Out:
# Entidades do tipo: body
# .       145566
# ,       122972
# de       70429
# /        53282
# -        45490
# :        45352
# e        33685
# a        29812
# o        26082
# do       24869
# da       21204
# 1        18643
# (        16060
# )        14231
# que      13480
# com      12628
# em       12090
# 2        11620
# '        11357
# no       10570
# para     10239
# as        9551
# ~         9266
# 3         9066
# DE        8831
# dtype: int64
# Entidades do tipo: PESSOA
# de           362
# DE           266
# .            186
# da           153
# José         143
# Bruno        126
# Alves        111
# PEREIRA      102
# DA           101
# -            100
# &             99
# Oliveira      87
# Lopes         86
# Guilherme     84
# SILVA         83
# Rua           82
# Fernandes     82
# BARBOSA       81
# Silva         81
# JORGE         81
# Santos        75
# Pires         74
# LOPES         73
# Gomes         73
# Barbosa       72
# dtype: int64
# Entidades do tipo: TEMPO
# /       18252
# 2013     5450
# 09       5362
# 11       3133
# de       2598
# 2014      986
# 2016      971
# 10        971
# 12        967
# .         904
# 2012      795
# 20        590
# 2015      554
# 01        489
# 13        480
# 26        436
# 07        423
# 19        420
# 05        416
# 7         393
# 17        377
# ,         375
# 18        355
# 08        353
# 6         338
# dtype: int64
# Entidades do tipo: LOCAL
# de          631
# -           608
# /           456
# Rua         454
# São         370
# DF          359
# Paulo       352
# Brasília    304
# do          295
# LTDA        291
# Rio         263
# .           258
# :           217
# SP          216
# Bairro      208
# Janeiro     191
# Brasil      182
# SUL         179
# DE          167
# Sul         163
# MG          143
# BRASIL      140
# PVC         137
# Jardim      135
# Marca       135
# dtype: int64
# Entidades do tipo: ORGANIZACAO
# de            2852
# LTDA          2329
# DE            1548
# do            1041
# E              933
# /              907
# da             894
# CIA            886
# e              761
# -              735
# Federal        638
# TCU            474
# União          467
# :              458
# EDUCAÇÃO       425
# DO             423
# Secretaria     415
# .              403
# Ministério     389
# A              384
# DA             375
# Tribunal       366
# S              366
# INSTITUTO      365
# COMERCIO       364
# dtype: int64
# Entidades do tipo: JURISPRUDENCIA
# .           705
# /           671
# -           351
# n           261
# °           258
# Acórdão     203
# 1           103
# 2            83
# 2013         66
# N            61
# Plenário     60
# 2010         52
# Processo     46
# 2003         42
# 2007         40
# TC           39
# 2009         38
# 5            37
# 3            35
# 214          33
# 2012         29
# 02           29
# 2015         28
# 0001         27
# Decisão      26
# dtype: int64
# Entidades do tipo: LEGISLACAO
# .          4963
# ,          3128
# Lei        2221
# /          2155
# da         1828
# n          1750
# °          1697
# 8          1233
# do         1001
# 666         963
# de          718
# 93          620
# artigo      602
# 000         575
# 1           522
# e           480
# Decreto     449
# 2           422
# 3           414
# nº          408
# 10          404
# Federal     390
# -           388
# 7           363
# inciso      345
# dtype: int64

# %% [markdown]
# ### Storing entities found

# %%
"""  Let"s store the data """
excel_filename = RELATIVE_PATH_TO_FOLDER + DATA_FILENAME + "_treated.xlsx"

# %%
"""  Convert the dataframe to an xlsx file """
df_sample.to_excel(excel_filename)

print("Stored tread dataset on ", excel_filename)
# Out:
# Stored tread dataset on  ./assets/datasets/judicial_data_treated.xlsx
